# %%
import wiki

# %%
search = wiki.CategorySearch('mathematics', limit=5)
col = search.execute()

# %%
it = wiki.Collection.flatten(col)

# %%
a = next(it)

# %%
a.get_links()
# Out:
# ['[[Mathematics]]',
#  '[[number]]',
#  '[[space]]',
#  '[[Mathematical structure|structure]]',
#  '[[Change (mathematics)|change]]',
#  '[[Definitions of mathematics]]',
#  '[[Language of mathematics]]',
#  '[[mathematician]]',
#  '[[Mathematics|mathematical]]',
#  '[[Philosophy of mathematics]]',
#  '[[Classical mathematics]]',
#  '[[logic]]',
#  '[[ZFC set theory]]',
#  '[[Constructivism (philosophy of mathematics)|Constructive mathematics]]',
#  '[[Impredicativity|Predicative mathematics]]',
#  '[[academic discipline]]',
#  '[[formal science]]',
#  '[[Mathematical object]]',
#  '[[abstract concept]]',
#  '[[mathematics]]',
#  '[[deductive reasoning]]',
#  '[[mathematical proof]]',
#  '[[Mathematical object]]',
#  '[[Object (philosophy)|Object]]',
#  '[[Abstract and concrete]]',
#  '[[Mathematical structure]]',
#  '[[Set (mathematics)|set]]',
#  '[[Operation (mathematics)|operation]]',
#  '[[Relation (math)|relation]]',
#  '[[Metric (mathematics)|metric]]',
# ...

# %%
s = wiki.ArticleSearch('Logarithm')

# %%
col = s.execute()

# %%
a_it = wiki.Collection.flatten(col)

# %%
len(list(a_it))
# Out:
# 50
